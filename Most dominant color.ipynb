# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Priyankk18k/Most-dominant-color-unsupervised-learning/blob/master/Most%20dominant%20color.ipynb)

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-b7328029-8523-441a-8540-626cdd3f08d3" name="files[]" multiple disabled />
#      <output id="result-b7328029-8523-441a-8540-626cdd3f08d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image.jpg.jpg to image.jpg.jpg
# User uploaded file "image.jpg.jpg" with length 98022 bytes

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
image = cv2.imread('image.jpg.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image.shape
# Out:
# (808, 766, 3)

# %%
plt.figure()
plt.axis("off")
plt.imshow(image)

# %%
image.shape
# Out:
# (808, 766, 3)

# %%
image = image.reshape((image.shape[0] * image.shape[1], 3))
print image
print image.shape
# Out:
# [[255 255 255]
#  [255 255 255]
#  [255 255 255]
#  ...
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]]
# (618928, 3)

# %%
from sklearn.cluster import KMeans
K = 3
clf = KMeans(n_clusters=K)
clf.fit(image)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
#initialising the label dictionary
label = [0, 0, 0]

#finding count of data in each cluster
for x in clf.labels_:
    label[x] += 1

#Total Number of data points
label_sum = image.shape[0]

#converting to percentage
label = [float(x) / label_sum for x in label]
print label
# Out:
# [0.31337570767520617, 0.592663443890081, 0.09396084843471292]

# %%
# !pip install webcolors
# Out:
# Collecting webcolors
#   Downloading https://files.pythonhosted.org/packages/1d/44/c4902683be73beba20afd299705e11f0a753a01cc7f9d6a070841848605b/webcolors-1.8.1-py2.py3-none-any.whl
# Installing collected packages: webcolors
# Successfully installed webcolors-1.8.1
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import webcolors

centroids = [x.astype("uint8").tolist() for x in clf.cluster_centers_]

clr = [webcolors.rgb_to_hex(c) for c in centroids]

plt.pie(label, colors=clr, shadow=True) 
plt.axis('equal')
plt.show()
